# %%
import pandas as pd

# %%
#cargar la base de datos de peliculas
base_df = pd.read_csv('movies.csv', index_col='names')

# %%
base_df
# Out:
#                                               date_x  score  \
# names
# Creed III                                03/02/2023    73.0
# Avatar: The Way of Water                 12/15/2022    78.0
# The Super Mario Bros. Movie              04/05/2023    76.0
# Mummies                                  01/05/2023    70.0
# Supercell                                03/17/2023    61.0
# ...                                              ...    ...
# 20th Century Women                       12/28/2016    73.0
# Delta Force 2: The Colombian Connection  08/24/1990    54.0
# The Russia House                         12/21/1990    61.0
# Darkman II: The Return of Durant         07/11/1995    55.0
# The Swan Princess: A Royal Wedding       07/20/2020    70.0
#
#                                                                                      genre  \
# names
# Creed III                                                                    Drama, Action
# ...

# %%
##Conexión con una base de datos:
import sqlite3
con = sqlite3.connect("database_pelis.db")
cursor=con.cursor

# %%
#Transformación de cada elemento del csv en json y carga en couchdb mediante código.
#transformar
a = pd.read_csv('movies.csv')
csv_data = pd.read_csv("movies.csv", sep = ",")
csv_data.to_json("data_m.json", orient = "records")

# %%
#importar json a couch
import json
import couchdb
couch = couchdb.Server('http://admin:admin@localhost:5984')

# %%
#defino el nombre de la base destino
db_name = 'info_pelis'

if db_name in couch:
    db = couch[db_name]
else:
    db = couch.create(db_name)
archivo_json = 'data_m.json'

with open(archivo_json) as archivo:
    datos_json = json.load(archivo)
for documento in datos_json:
    db.update([documento])
